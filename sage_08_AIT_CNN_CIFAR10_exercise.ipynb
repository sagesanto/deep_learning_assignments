# %% [markdown]
# # Copyright
#
# <PRE>
# Copyright (c) Bálint Gyires-Tóth - All Rights Reserved
# You may use and modify this code for research and development purpuses.
# Using this code for educational purposes (self-paced or instructor led) without the permission of the author is prohibited.
# </PRE>

# %% [markdown]
# # Convolutional Neural Network exercise
#
# In this notebook, you will build a convolutional neural network, which offers superior results over the previous MLP solution. Additionally, you will perform a more detailed evaluation.

# %%
# imports
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, MaxPool2D, Flatten, Dropout, BatchNormalization
from tensorflow.keras.initializers import HeNormal
from tensorflow.keras.callbacks import EarlyStopping

# %% [markdown]
# # 1. Data
# The dataset we will use is the well-known CIFAR10 (Canadian Institute For Advanced Research). Explore the details on the Keras website first: https://keras.io/api/datasets/cifar10/
#
# There isn't much difference between the data preprocessing part and the one we did before. The only difference is that we don't have to reshape images into vectors, but we are working with a 4 dimensional data structure, where the dimensions are: batch, X, Y, and color channels.
#
# In the event that anything is not clear regarding the data preparation part, please check the previous CIFAR10 notebook.

# %%
(X_train, Y_train), (X_test, Y_test) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 13s 0us/step

# %%
# it is in int8 format, the neural network requires float32
X_train = X_train.astype("float32")
X_test = X_test.astype("float32")

# %%
train_ratio  = 0.8
train_length = X_train.shape[0]
train_split  = int(train_ratio*train_length)
X_valid, Y_valid = X_train[train_split:], Y_train[train_split:]
X_train, Y_train = X_train[:train_split], Y_train[:train_split]

# %%
mean = X_train.mean(axis=0)
std  = X_train.std(axis=0)

X_train = (X_train-mean)/std
X_valid = (X_valid-mean)/std
X_test  = (X_test-mean)/std

# %%
nb_classes = len(np.unique(Y_train))
Y_train = to_categorical(Y_train, nb_classes)
Y_valid = to_categorical(Y_valid, nb_classes)
Y_test  = to_categorical(Y_test, nb_classes)

# %%
print("Shapes of the training, validation and test input data:", X_train.shape, X_valid.shape, X_test.shape)
print("Shapes of the training, validation and test output data:", Y_train.shape, Y_valid.shape, Y_test.shape)
print("Mean values of the training, validation and test input data:", X_train.mean(), X_valid.mean(), X_test.mean())
print("Standard deviation of the training, validation and test input data:", X_train.std(), X_valid.std(), X_test.std())
# Out:
# Shapes of the training, validation and test input data: (40000, 32, 32, 3) (10000, 32, 32, 3) (10000, 32, 32, 3)
# Shapes of the training, validation and test output data: (40000, 10) (10000, 10) (10000, 10)
# Mean values of the training, validation and test input data: 2.2788842e-09 0.0023437198 0.013331206
# Standard deviation of the training, validation and test input data: 1.0000023 0.9965626 0.99783075

# %% [markdown]
# # 2. Exercise: training

# %% [markdown]
# Create and train a convolutional neural network with the following requirements:
# * apply early stopping with patience=5 and monitor the validation accuracy, don't forget to load back the best weights after early stopping
# * the number of trainable parameters is lower than 200.000
# * the validation accuracy must be higher than 72%
#
# Hints:
# * you can always inspect the number of trainable parameters per layer with model.summary()
# * usually the most trainable parameters are between the last convolutional layer and the next dense layer -- so you should have a reasonable output size at the last convolutional layer
# * regularization helps (e.g. DropOut and/or BatchNormalization)
# * use the right activation function at the output layer and the corresponding loss function
# * for the chosen activation functions, please use the appropriate initialization method
# * you can match the dimension of the last conv/pooling layer to the next dense layer with e.g. Flatten()
# * ADAM optimizer is a reasonable choice
# * don't forget to turn on GPU support in Colab, otherwise, it would be quite slow to train the networks

# %%
es = EarlyStopping(patience=5,monitor="val_accuracy",mode="max",restore_best_weights=True,verbose=1)

# %%
# model definition
model = Sequential()


activation = "relu"
initializer = "HeNormal"

model.add(Conv2D(filters=50,kernel_size=(5,5),activation=activation,kernel_initializer=initializer,input_shape=(32,32,3),padding="same"))
model.add(MaxPool2D())
model.add(BatchNormalization())
model.add(Conv2D(filters=10,kernel_size=(3,3),activation=activation,kernel_initializer=initializer,padding="same"))
model.add(MaxPool2D())
model.add(BatchNormalization())
model.add(Conv2D(filters=10,kernel_size=(3,3),activation=activation,kernel_initializer=initializer,padding="same"))
model.add(MaxPool2D())
model.add(BatchNormalization())
# model.add(Conv2D(filters=5,kernel_size=(5,5),activation=activation,kernel_initializer=initializer))
model.add(Flatten())
model.add(Dense(256,activation=activation,kernel_initializer=initializer))
model.add(Dropout(0.5))
model.add(Dense(256,activation=activation,kernel_initializer=initializer))
model.add(Dropout(0.5))
model.add(Dense(256,activation=activation,kernel_initializer=initializer))
model.add(Dropout(0.5))

model.add(Dense(nb_classes,activation="softmax"))

# loss function and optimizer
model.compile(loss='categorical_crossentropy', optimizer='adam',metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_20"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_59 (Conv2D)              │ (None, 32, 32, 50)     │         3,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_30 (MaxPooling2D) │ (None, 16, 16, 50)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_44          │ (None, 16, 16, 50)     │           200 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_60 (Conv2D)              │ (None, 16, 16, 10)     │         4,510 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_31 (MaxPooling2D) │ (None, 8, 8, 10)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_45          │ (None, 8, 8, 10)       │            40 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_61 (Conv2D)              │ (None, 8, 8, 10)       │           910 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_32 (MaxPooling2D) │ (None, 4, 4, 10)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_46          │ (None, 4, 4, 10)       │            40 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_19 (Flatten)            │ (None, 160)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_49 (Dense)                │ (None, 256)            │        41,216 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_30 (Dropout)            │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_50 (Dense)                │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_31 (Dropout)            │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_51 (Dense)                │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_32 (Dropout)            │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_52 (Dense)                │ (None, 10)             │         2,570 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 184,870 (722.15 KB)
#  Trainable params: 184,730 (721.60 KB)
#  Non-trainable params: 140 (560.00 B)

# %% [markdown]
# Please, check the number of trainable paramers:

# %%
print("#trainable parameters:",model.count_params())
# Out:
# #trainable parameters: 184870

# %%
# training
network_history = model.fit(X_train, Y_train, batch_size=64, epochs=1000, validation_data=(X_valid, Y_valid), verbose=2, callbacks=[es])
# Out:
# Epoch 1/1000
# 625/625 - 13s - 20ms/step - accuracy: 0.2244 - loss: 2.2204 - val_accuracy: 0.3731 - val_loss: 1.7109
# Epoch 2/1000
# 625/625 - 3s - 5ms/step - accuracy: 0.3487 - loss: 1.7134 - val_accuracy: 0.4584 - val_loss: 1.4999
# Epoch 3/1000
# 625/625 - 4s - 6ms/step - accuracy: 0.4301 - loss: 1.5454 - val_accuracy: 0.5063 - val_loss: 1.3951
# Epoch 4/1000
# 625/625 - 3s - 5ms/step - accuracy: 0.4798 - loss: 1.4345 - val_accuracy: 0.5473 - val_loss: 1.2749
# Epoch 5/1000
# 625/625 - 3s - 5ms/step - accuracy: 0.5171 - loss: 1.3501 - val_accuracy: 0.5680 - val_loss: 1.2272
# Epoch 6/1000
# 625/625 - 3s - 5ms/step - accuracy: 0.5476 - loss: 1.2765 - val_accuracy: 0.5938 - val_loss: 1.1562
# Epoch 7/1000
# 625/625 - 5s - 8ms/step - accuracy: 0.5702 - loss: 1.2196 - val_accuracy: 0.6094 - val_loss: 1.1159
# Epoch 8/1000
# 625/625 - 3s - 5ms/step - accuracy: 0.5840 - loss: 1.1828 - val_accuracy: 0.6346 - val_loss: 1.0611
# Epoch 9/1000
# 625/625 - 5s - 9ms/step - accuracy: 0.6043 - loss: 1.1368 - val_accuracy: 0.6356 - val_loss: 1.0401
# Epoch 10/1000
# 625/625 - 5s - 8ms/step - accuracy: 0.6190 - loss: 1.0952 - val_accuracy: 0.6528 - val_loss: 0.9890
# Epoch 11/1000
# 625/625 - 3s - 5ms/step - accuracy: 0.6334 - loss: 1.0612 - val_accuracy: 0.6565 - val_loss: 0.9831
# Epoch 12/1000
# 625/625 - 3s - 5ms/step - accuracy: 0.6428 - loss: 1.0341 - val_accuracy: 0.6645 - val_loss: 0.9662
# Epoch 13/1000
# 625/625 - 3s - 5ms/step - accuracy: 0.6515 - loss: 1.0075 - val_accuracy: 0.6646 - val_loss: 0.9438
# Epoch 14/1000
# 625/625 - 5s - 9ms/step - accuracy: 0.6606 - loss: 0.9794 - val_accuracy: 0.6798 - val_loss: 0.9160
# Epoch 15/1000
# 625/625 - 3s - 5ms/step - accuracy: 0.6674 - loss: 0.9596 - val_accuracy: 0.6904 - val_loss: 0.8860
# Epoch 16/1000
# 625/625 - 3s - 5ms/step - accuracy: 0.6747 - loss: 0.9415 - val_accuracy: 0.6850 - val_loss: 0.8928
# Epoch 17/1000
# 625/625 - 5s - 8ms/step - accuracy: 0.6816 - loss: 0.9246 - val_accuracy: 0.6875 - val_loss: 0.8954
# Epoch 18/1000
# 625/625 - 3s - 5ms/step - accuracy: 0.6878 - loss: 0.9063 - val_accuracy: 0.6979 - val_loss: 0.8627
# Epoch 19/1000
# 625/625 - 5s - 8ms/step - accuracy: 0.6935 - loss: 0.8945 - val_accuracy: 0.6823 - val_loss: 0.9243
# Epoch 20/1000
# 625/625 - 5s - 8ms/step - accuracy: 0.6963 - loss: 0.8822 - val_accuracy: 0.7028 - val_loss: 0.8600
# Epoch 21/1000
# 625/625 - 3s - 5ms/step - accuracy: 0.7014 - loss: 0.8734 - val_accuracy: 0.7071 - val_loss: 0.8422
# Epoch 22/1000
# 625/625 - 3s - 5ms/step - accuracy: 0.7046 - loss: 0.8556 - val_accuracy: 0.7071 - val_loss: 0.8486
# Epoch 23/1000
# 625/625 - 5s - 8ms/step - accuracy: 0.7115 - loss: 0.8426 - val_accuracy: 0.7065 - val_loss: 0.8416
# Epoch 24/1000
# 625/625 - 3s - 5ms/step - accuracy: 0.
1000
# 625/625 - 3s - 5ms/step - accuracy: 0.7672 - loss: 0.6744 - val_accuracy: 0.7317 - val_loss: 0.7942
# Epoch 53/1000
# 625/625 - 5s - 8ms/step - accuracy: 0.7670 - loss: 0.6725 - val_accuracy: 0.7258 - val_loss: 0.8083
# Epoch 54/1000
# 625/625 - 6s - 9ms/step - accuracy: 0.7686 - loss: 0.6732 - val_accuracy: 0.7333 - val_loss: 0.7954
# Epoch 55/1000
# 625/625 - 4s - 6ms/step - accuracy: 0.7673 - loss: 0.6684 - val_accuracy: 0.7259 - val_loss: 0.8146
# Epoch 56/1000
# 625/625 - 3s - 5ms/step - accuracy: 0.7719 - loss: 0.6616 - val_accuracy: 0.7304 - val_loss: 0.7980
# Epoch 57/1000
# 625/625 - 5s - 8ms/step - accuracy: 0.7701 - loss: 0.6669 - val_accuracy: 0.7307 - val_loss: 0.7920
# Epoch 58/1000
# 625/625 - 3s - 5ms/step - accuracy: 0.7688 - loss: 0.6608 - val_accuracy: 0.7292 - val_loss: 0.7964
# Epoch 59/1000
# 625/625 - 5s - 8ms/step - accuracy: 0.7764 - loss: 0.6552 - val_accuracy: 0.7340 - val_loss: 0.7907
# Epoch 60/1000
# 625/625 - 3s - 5ms/step - accuracy: 0.7765 - loss: 0.6524 - val_accuracy: 0.7333 - val_loss: 0.7945
# Epoch 61/1000
# 625/625 - 4s - 6ms/step - accuracy: 0.7730 - loss: 0.6508 - val_accuracy: 0.7300 - val_loss: 0.8036
# Epoch 62/1000
# 625/625 - 3s - 5ms/step - accuracy: 0.7773 - loss: 0.6477 - val_accuracy: 0.7270 - val_loss: 0.8034
# Epoch 63/1000
# 625/625 - 3s - 5ms/step - accuracy: 0.7780 - loss: 0.6432 - val_accuracy: 0.7318 - val_loss: 0.8026
# Epoch 64/1000
# 625/625 - 3s - 5ms/step - accuracy: 0.7802 - loss: 0.6382 - val_accuracy: 0.7296 - val_loss: 0.8091
# Epoch 64: early stopping
# Restoring model weights from the end of the best epoch: 59.

# %%
def plot_history(network_history):
    plt.figure()
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.plot(network_history.history['loss'])
    plt.plot(network_history.history['val_loss'])
    plt.legend(['Training', 'Validation'])

    plt.figure()
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.plot(network_history.history['accuracy'])
    plt.plot(network_history.history['val_accuracy'])
    plt.legend(['Training', 'Validation'], loc='lower right')
    plt.show()

plot_history(network_history)

# %% [markdown]
# # 3. Exercise: evaluation on test data
# You will evaluate the classification of the test data using the common metrics and the confusion matrix in this section.
#
#
# As a first stes, let's run the predictions and convert the predicted softmax outputs to dense labels. The one-hot encoded labels are also converted back to dense labels, as they are required for the evaluation functions.

# %%
probas = model.predict(X_test)
preds  = np.argmax(probas,axis=1)
Y_test_dense = np.argmax(Y_test, axis=1) # get the original dense labels of the test data
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step

# %% [markdown]
# ## 3.1. Exercise: Metrics
# please review the common classification metrics (accuracy, precision, recall, F1) for the complete model (not per class).
#
# Hints:
# * use macro averaging
# * you have to import the right functions from [sklearn.metrics](https://scikit-learn.org/stable/modules/model_evaluation.html)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
print("Accuracy:",accuracy_score(Y_test_dense,preds))
print("Precision:",precision_score(Y_test_dense,preds,average="macro"))
print("Recall:",recall_score(Y_test_dense,preds,average="macro"))
print("F1:",f1_score(Y_test_dense,preds,average="macro"))
# Out:
# Accuracy: 0.7285
# Precision: 0.7282130524742345
# Recall: 0.7285000000000001
# F1: 0.7277046955777415

# %% [markdown]
# ## 3.2. Exercise: Confusion matrix
# Calculate the confusion matrix and display the results in a heatmap (with decimal values).
#
# Hints:
# * you have to do the imports this time too, e.g. from [sklearn.metrics](https://scikit-learn.org/stable/modules/model_evaluation.html) and the [heatmap function](https://seaborn.pydata.org/generated/seaborn.heatmap.html) of [seaborn](https://seaborn.pydata.org/)
# * for displaying the decimal values, you have to turn annot=True and define fmt='d' in the heatmap function of seaborn

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

# %%
conf = confusion_matrix(Y_test_dense,preds)
plt.figure(figsize=(7,6))
_=sns.heatmap(conf,annot=True,fmt='d')
